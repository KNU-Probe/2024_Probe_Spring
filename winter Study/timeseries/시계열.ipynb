# %% [markdown]
# # 시계열
#
# ## 시계열 데이터란.
# ### 시간의 흐름에 따라 기록 자료를 뜻하고 이를 분석하는 것을 시계열 분석이라고 함
#
#
#
#
#
#
# 시계열 데이터의 특징.

# %% [markdown]
# ## 시계열 데이터의 예시

# %% [markdown]
# ## 시계열 데이터의 특징
#
# ### 정상성

# %% [markdown]
# ### 계절성

# %% [markdown]
# # 시계열 데이터 처리방법

# %% [markdown]
# # 시계열 분석 모형
# ## 1.AR

# %% [markdown]
# ## 2.MA

# %% [markdown]
# ## 3.ARIMA

# %% [markdown]
# # 추가적인 것들
# ## 그레인저 인과검정.

# %% [markdown]
# ## 충격반응함수

# %% [markdown]
# ## 공적분 검정
