# %% [markdown]
# <a href="https://colab.research.google.com/github/KNU-Probe/2024_Probe_Spring/blob/main/%EC%8B%9C%EA%B3%84%EC%97%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
#working with datetime index

dt1 = dt.datetime(2021,1,1)
dt2 = pd.Timestamp(2021-1-1)
dt3 = pd.to_datetime('2021-1-1')

#이중에서 가장 이해하기 쉬운 걸로 사용하자.

# %%
print(dt1)
print(dt2)
print(dt3)
# Out:
# 2021-01-01 00:00:00
# 1970-01-01 00:00:00.000002019
# 2021-01-01 00:00:00

# %%
print(type(dt1))
print(type(dt2))
print(type(dt3))
# Out:
# <class 'datetime.datetime'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
dt1 ==  dt3
# Out:
# True

# %%
dates = ['2021-1-1' , '2021-1-2']
pd_dates = pd.to_datetime(dates)
print(pd_dates)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02'], dtype='datetime64[ns]', freq=None)

# %%
print(type(pd_dates))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
dates = ['2021-01-01',
         '2/1/2021',
         '03-01-2021',
         'April 1, 2021',
         '20210501',
         np.datetime64('2021-07-01'),
         dt.datetime(2021, 8 , 1),
         pd.Timestamp(2021,9,1)
         ]

# %%
pd.to_datetime(dates,
               infer_datetime_format=True,
               errors = 'coerce')
# Out:
# DatetimeIndex(['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-07-01', '2021-08-01', '2021-09-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start = '2021-01-01' , periods = 3 , freq = 'D')
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03'], dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '2021-01-01',
              end = '2021-01-03',
              freq = 'D')
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03'], dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '2021-01-01',
              end = '2021-01-03',
              periods = 2)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start = '2021-01-01',
              end = '2021-01-03',
              periods = 10)
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 05:20:00',
#                '2021-01-01 10:40:00', '2021-01-01 16:00:00',
#                '2021-01-01 21:20:00', '2021-01-02 02:40:00',
#                '2021-01-02 08:00:00', '2021-01-02 13:20:00',
#                '2021-01-02 18:40:00', '2021-01-03 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
#providing a format argument to datetime
dt.datetime.strptime('1/1/2022', '%m/%d/%Y')
dt.datetime.strptime('1 January, 2022' , '%d %B, %Y')

dt.datetime.strptime('Saturday, January 1, 2022', '%A, %B %d, %Y')
# Out:
# datetime.datetime(2022, 1, 1, 0, 0)

# %%
dt_2 = pd.to_datetime('1/1/2022', format = '%m/%d/%Y')
print(dt_2)
# Out:
# 2022-01-01 00:00:00

# %%
pd.to_datetime('Saturday, January 1 ,2022')
# Out:
# Timestamp('2022-01-01 00:00:00')

# %%
df = pd.DataFrame(
    {'Date':['January 1 , 2022', 'January 2 , 2022',
             'January 3 , 2022'],
     'Sales' : [23000, 19020,21000]}
    )
df
# Out:
#                Date  Sales
# 0  January 1 , 2022  23000
# 1  January 2 , 2022  19020
# 2  January 3 , 2022  21000

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#         Date  Sales
# 0 2022-01-01  23000
# 1 2022-01-02  19020
# 2 2022-01-03  21000

# %%
df.set_index('Date',inplace = True)

# %%
df
# Out:
#             Sales
# Date
# 2022-01-01  23000
# 2022-01-02  19020
# 2022-01-03  21000

# %%
#time delta 시간에 대한 연산
df = pd.DataFrame(
        {
        'item': ['item1', 'item2', 'item3', 'item4', 'item5', 'item6'],
        'purchase_dt': pd.date_range('2021-01-01', periods=6, freq='D', tz='UTC')
        }
)
df
# Out:
#     item               purchase_dt
# 0  item1 2021-01-01 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00

# %%
df['expiration_dt'] = df['purchase_dt'] + pd.Timedelta(days=30) #구매일자에서 30일을 더하자
df
# Out:
#     item               purchase_dt             expiration_dt
# 0  item1 2021-01-01 00:00:00+00:00 2021-01-31 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00 2021-02-01 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00 2021-02-02 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00 2021-02-03 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00 2021-02-04 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00 2021-02-05 00:00:00+00:00

# %%
df['extended_dt'] = df['purchase_dt'] + pd.Timedelta('35 days 12 hours 30 minutes')
df
# Out:
#     item               purchase_dt             expiration_dt  \
# 0  item1 2021-01-01 00:00:00+00:00 2021-01-31 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00 2021-02-01 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00 2021-02-02 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00 2021-02-03 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00 2021-02-04 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00 2021-02-05 00:00:00+00:00
#
#                 extended_dt
# 0 2021-02-05 12:30:00+00:00
# 1 2021-02-06 12:30:00+00:00
# 2 2021-02-07 12:30:00+00:00
# 3 2021-02-08 12:30:00+00:00
# 4 2021-02-09 12:30:00+00:00
# 5 2021-02-10 12:30:00+00:00

# %%
df['exp_ext_diff'] = (
         df['extended_dt'] - df['expiration_dt']
        )
df
# Out:
#     item               purchase_dt             expiration_dt  \
# 0  item1 2021-01-01 00:00:00+00:00 2021-01-31 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00 2021-02-01 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00 2021-02-02 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00 2021-02-03 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00 2021-02-04 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00 2021-02-05 00:00:00+00:00
#
#                 extended_dt    exp_ext_diff
# 0 2021-02-05 12:30:00+00:00 5 days 12:30:00
# 1 2021-02-06 12:30:00+00:00 5 days 12:30:00
# 2 2021-02-07 12:30:00+00:00 5 days 12:30:00
# 3 2021-02-08 12:30:00+00:00 5 days 12:30:00
# 4 2021-02-09 12:30:00+00:00 5 days 12:30:00
# 5 2021-02-10 12:30:00+00:00 5 days 12:30:00

# %%
import pandas as pd

df = pd.DataFrame(
        {
        'item': ['item1', 'item2', 'item3', 'item4', 'item5', 'item6'],
        'purchase_dt': pd.date_range('2021-01-01', periods=6, freq='D', tz='GMT')
        }
)
df
# Out:
#     item               purchase_dt
# 0  item1 2021-01-01 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00

# %%
df.iloc[:,1:] = df.iloc[: ,1:].apply(
            lambda x: x.dt.tz_convert('US/Pacific')
                )
df
# Out:
# <ipython-input-33-82b6ed528fdf>:1: FutureWarning: Setitem-like behavior with mismatched timezones is deprecated and will change in a future version. Instead of raising (or for Index, Series, and DataFrame methods, coercing to object dtype), the value being set (or passed as a fill_value, or inserted) will be cast to the existing DatetimeArray/DatetimeIndex/Series/DataFrame column's timezone. To retain the old behavior, explicitly cast to object dtype before the operation.
#   df.iloc[:,1:] = df.iloc[: ,1:].apply(
#     item               purchase_dt
# 0  item1 2020-12-31 16:00:00-08:00
# 1  item2 2021-01-01 16:00:00-08:00
# 2  item3 2021-01-02 16:00:00-08:00
# 3  item4 2021-01-03 16:00:00-08:00
# 4  item5 2021-01-04 16:00:00-08:00
# 5  item6 2021-01-05 16:00:00-08:00

# %%
df.iloc[:,1:] = df.iloc[: ,1:].apply(
            lambda x: x.dt.tz_convert('GMT')
                )
df
# Out:
# <ipython-input-34-be8f33667451>:1: FutureWarning: Setitem-like behavior with mismatched timezones is deprecated and will change in a future version. Instead of raising (or for Index, Series, and DataFrame methods, coercing to object dtype), the value being set (or passed as a fill_value, or inserted) will be cast to the existing DatetimeArray/DatetimeIndex/Series/DataFrame column's timezone. To retain the old behavior, explicitly cast to object dtype before the operation.
#   df.iloc[:,1:] = df.iloc[: ,1:].apply(
#     item               purchase_dt
# 0  item1 2021-01-01 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   item         6 non-null      object
#  1   purchase_dt  6 non-null      datetime64[ns, GMT]
# dtypes: datetime64[ns, GMT](1), object(1)
# memory usage: 224.0+ bytes

# %%
df['1 week'] = pd.Timedelta('1W')

# %%
df
# Out:
#     item               purchase_dt 1 week
# 0  item1 2021-01-01 00:00:00+00:00 7 days
# 1  item2 2021-01-02 00:00:00+00:00 7 days
# 2  item3 2021-01-03 00:00:00+00:00 7 days
# 3  item4 2021-01-04 00:00:00+00:00 7 days
# 4  item5 2021-01-05 00:00:00+00:00 7 days
# 5  item6 2021-01-06 00:00:00+00:00 7 days

# %%
df['1_week_more'] = df['purchase_dt'] + df['1 week']
df['1_week_less'] = df['purchase_dt'] - df['1 week']
df
# Out:
#     item               purchase_dt 1 week               1_week_more  \
# 0  item1 2021-01-01 00:00:00+00:00 7 days 2021-01-08 00:00:00+00:00
# 1  item2 2021-01-02 00:00:00+00:00 7 days 2021-01-09 00:00:00+00:00
# 2  item3 2021-01-03 00:00:00+00:00 7 days 2021-01-10 00:00:00+00:00
# 3  item4 2021-01-04 00:00:00+00:00 7 days 2021-01-11 00:00:00+00:00
# 4  item5 2021-01-05 00:00:00+00:00 7 days 2021-01-12 00:00:00+00:00
# 5  item6 2021-01-06 00:00:00+00:00 7 days 2021-01-13 00:00:00+00:00
#
#                 1_week_less
# 0 2020-12-25 00:00:00+00:00
# 1 2020-12-26 00:00:00+00:00
# 2 2020-12-27 00:00:00+00:00
# 3 2020-12-28 00:00:00+00:00
# 4 2020-12-29 00:00:00+00:00
# 5 2020-12-30 00:00:00+00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   item         6 non-null      object
#  1   purchase_dt  6 non-null      datetime64[ns, GMT]
#  2   1 week       6 non-null      timedelta64[ns]
#  3   1_week_more  6 non-null      datetime64[ns, GMT]
#  4   1_week_less  6 non-null      datetime64[ns, GMT]
# dtypes: datetime64[ns, GMT](3), object(1), timedelta64[ns](1)
# memory usage: 368.0+ bytes

# %%
pd.timedelta_range('1W 2 days', periods=5)
# Out:
# TimedeltaIndex(['9 days', '10 days', '11 days', '12 days', '13 days'], dtype='timedelta64[ns]', freq='D')

# %%
df = pd.DataFrame(
        {
        'item': ['item1', 'item2', 'item3', 'item4', 'item5'],
        'purchase_dt': pd.date_range('2021-01-01', periods=5, freq='D', tz='GMT'),
        'time_deltas': pd.timedelta_range('1W 2 days 6 hours', periods=5)
        }

)

# %%
df
# Out:
#     item               purchase_dt      time_deltas
# 0  item1 2021-01-01 00:00:00+00:00  9 days 06:00:00
# 1  item2 2021-01-02 00:00:00+00:00 10 days 06:00:00
# 2  item3 2021-01-03 00:00:00+00:00 11 days 06:00:00
# 3  item4 2021-01-04 00:00:00+00:00 12 days 06:00:00
# 4  item5 2021-01-05 00:00:00+00:00 13 days 06:00:00

# %% [markdown]
# # Recipe 6: Working with Date Offets

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(10)
df = pd.DataFrame(
        {
        'purchase_dt': pd.date_range('2021-01-01', periods=6, freq='D'),
        'production' : np.random.randint(4, 20, 6) #4에서 20사이의 숫자를 6개 만들어내라
        }).set_index('purchase_dt')
df
# Out:
#              production
# purchase_dt
# 2021-01-01           13
# 2021-01-02           17
# 2021-01-03            8
# 2021-01-04           19
# 2021-01-05            4
# 2021-01-06            5

# %%
df['day'] = df.index.day_name()

# %%
df
# Out:
#              production        day
# purchase_dt
# 2021-01-01           13     Friday
# 2021-01-02           17   Saturday
# 2021-01-03            8     Sunday
# 2021-01-04           19     Monday
# 2021-01-05            4    Tuesday
# 2021-01-06            5  Wednesday

# %% [markdown]
# # Recipe 7: Working with custom business days

# %% [markdown]
# # Recipe 1. Plotting Time Series Data using pandas

# %% [markdown]
# # Recipe 2. Plotting Time Series with Interactive Visualization using hvplot and Plotly Express

# %% [markdown]
# # Recipe 3. Decomposing Time Series

# %% [markdown]
# # Recipe 4. Detecting Time Series Stationarity

# %% [markdown]
# # Recipe 6. Testing for Autocorrelation

# %% [markdown]
# # Recipe 1. Plotting ACF and PACF

# %% [markdown]
# # Recipe 3. Forecasting Univariate Time Series Data with Non-Seasonal ARIMA

# %% [markdown]
# # Recipe 4. Forecasting Univariate Time Series Data with Seasonal ARIMA

# %% [markdown]
# https://direction-f.tistory.com/66
#
# https://lsjsj92.tistory.com/584
#
#
# https://sosoeasy.tistory.com/400
